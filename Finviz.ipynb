# %% [markdown]
# <a href="https://colab.research.google.com/github/karloxkronfeld/Finanzas/blob/main/Finviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
def leer_pagina(url): 

  header = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36","X-Requested-With": "XMLHttpRequest"}

  r = requests.get(url, headers=header)
  dfs = pd.read_html(r.text)
  dfs=dfs[-2]
  dfs.columns=dfs.loc[0]
  dfs=dfs[1:].iloc[:,1:]
  return(dfs)

# %%
semanal = leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf1w")
mensual = leer_pagina('https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf4w')
quat =    leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf13w")
semestre= leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf26w")
anual   = leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf52w")

# %%
semanal
# Out:
# 0  Ticker Perf Week Perf Month Perf Quart  ... Rel Volume   Price  Change   Volume
# 1    WEBL    29.58%     43.48%     60.01%  ...       1.99   89.31   2.24%    19744
# 2    LABU    28.79%     53.49%    135.23%  ...       1.25  171.87   5.77%   205475
# 3    BNKU    28.07%     -0.89%    144.13%  ...       1.92   30.72   2.64%    43967
# 4    HIBL    27.15%      7.37%    149.16%  ...       1.55  291.76   4.58%     8538
# 5    DPST    26.77%     10.86%    175.87%  ...       0.92  174.16   3.36%    64243
# 6    POTX    26.55%     55.38%    127.95%  ...       7.17   19.38   5.62%   373757
# 7    NRGU    26.29%      8.32%    207.79%  ...       2.04   91.87  10.22%   163472
# 8    THCX    25.15%     42.13%    126.24%  ...       4.54   21.96   4.82%   174002
# 9    URTY    24.97%     25.79%    154.94%  ...       1.46  117.34   5.11%   225102
# 10    TNA    24.82%     25.84%    155.09%  ...       0.97   98.75   5.11%  1380404
# 11   CNBS    24.74%     44.79%    129.45%  ...       6.83   30.52   4.56%   140438
# 12   DFEN    24.48%      5.59%     64.34%  ...       0.87   17.53   1.98%   404611
# 13   FNGU    23.86%     38.27%     78.65%  ...       1.24  373.10   2.25%    88440
# 14   YOLO    23.64%     36.75%    111.79%  ...       5.13   26.93   3.38%   415156
# 15   BOIL    23.50%     11.90%    -26.32%  ...       1.21   26.72   1.10%   462818
# 16     MJ    22.62%     41.40%    106.91%  ...       2.16   24.42   4.54%   999034
# 17   NAIL    21.52%     46.36%     23.98%  ...       1.33   70.60   8.45%   198013
# 18   CWEB    21.08%     49.32%     50.22%  ...       1.92   92.91   0.49%    18840
# 19    FAS    20.51%      3.11%     87.91%  ...       1.42   70.19   2.17%   605770
# 20   TOKE    19.92%     31.07%     81.92%  ...       5.60   22.33   4.18%    28568
#
# [20 rows x 15 columns]
