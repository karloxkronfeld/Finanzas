# %% [markdown]
# <a href="https://colab.research.google.com/github/karloxkronfeld/Finanzas/blob/main/LeerFinviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
def leer_pagina(url): 

  header = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36","X-Requested-With": "XMLHttpRequest"}

  r = requests.get(url, headers=header)
  dfs = pd.read_html(r.text)
  dfs=dfs[-2]
  dfs.columns=dfs.loc[0]
  dfs=dfs[1:].iloc[:,1:]
  return(dfs)

# %%
semanal = leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf1w")
mensual = leer_pagina('https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf4w')
quat =    leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf13w")
semestre= leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf26w")
anual   = leer_pagina("https://finviz.com/screener.ashx?v=141&f=ind_exchangetradedfund&o=-perf52w")

# %%
semanal
# Out:
# 0  Ticker Perf Week Perf Month Perf Quart  ... Rel Volume   Price   Change    Volume
# 1    BDRY    25.77%     26.24%    115.29%  ...       2.97   13.52  -18.85%    361117
# 2    LABD    22.70%     -9.71%    -55.21%  ...       1.54   16.92    8.05%   3525741
# 3    BLOK    17.59%     46.10%    112.93%  ...       3.13   58.28   -3.67%   2124472
# 4    JDST    15.69%      7.18%     10.49%  ...       0.87   11.80    3.78%   4358957
# 5    DUST    15.15%     10.34%     19.20%  ...       0.86   22.72    2.57%   2956166
# 6    BNKU    13.90%     13.08%    102.25%  ...       1.19   35.88   -0.91%    165375
# 7     TMV     9.37%     14.41%     24.48%  ...       1.77   68.19    1.23%    526659
# 8     TTT     9.16%     14.04%     23.97%  ...       2.08   38.01    1.09%    237305
# 9    COPX     9.10%     14.59%     49.48%  ...       3.60   37.16    0.92%   1131609
# 10    TZA     8.69%    -11.30%    -51.77%  ...       1.72    4.63    4.75%  53944942
# 11   SRTY     8.47%    -11.67%    -52.02%  ...       1.86   11.66    4.86%   4461245
# 12    GLL     7.76%      7.22%     11.38%  ...       0.74   35.43    0.03%     59179
# 13    DZZ     7.19%      8.00%     11.03%  ...       0.60    2.97   -0.17%      5779
# 14    FAS     6.94%      9.51%     51.79%  ...       0.85   76.55   -1.47%   1901147
# 15   SOXL     6.72%      2.44%     74.86%  ...       1.39  640.28   -3.01%   1035607
# 16   URNM     6.49%     27.04%     92.97%  ...       2.92   55.48   -7.75%    158763
# 17    BIS     6.43%     -1.16%    -29.11%  ...       2.53   19.53    3.44%    184773
# 18    GRU     6.31%     -0.71%     27.58%  ...       3.62    4.21    2.93%     20470
# 19   NRGU     6.28%     14.10%    110.47%  ...       0.57  104.69   -6.58%    262223
# 20    TBT     6.13%      9.40%     15.93%  ...       2.42   19.21    0.84%   5128057
#
# [20 rows x 15 columns]
